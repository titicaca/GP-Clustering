# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy

#plot the scatter plot
def plotScatter(X,Y,title,c):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(X,Y,c+'.')
    ax.set_title(title)
    plt.show()
    
#init parameters for the model
alpha = 1

# %%
#Calculate Covariance Matrix C
def kernelFunction(x1, x2):
    c = 0;
    for i in range(len(x1)):
        c += alpha * (x1[i] - x2[i]) **2

    c = math.exp(- 0.5 * c)
    return c

#calculate the whole covariance matrix 
def getCovarianceMatrix(data):
    size = len(data[0,:])
    C = [[ 0 for i in range (size)] for j in range (size)]
    for i in range (size):
        for j in range (size):
            C[i][j] = kernelFunction(data[:,i], data[:,j])
    return matrix(C)  


#calculate matrix k for new data point x 
def getMatrix_k(x, data):
    size = len(data[0,:])
    k = [ 0 for i in range (size) ]
    for i in range (size):
        k[i] = kernelFunction(x, data[:,i])
    return matrix(k).T

#TODO check how to calculate the variance
#calculate variance of dataset
def getVariance(data):
    return np.var(data)

#calculate inversion of Matrix A
def getInversionMatrix(data, C):
    size = len(data[0,:])
    var = getVariance(data)
    return  (C + var * matrix(np.eye(size)) ).I 

#calcalate the variance for a given point x
def varianceFunction(x, data, inv):
    k = getMatrix_k(x,data)
    result = kernelFunction(x,x) - k.T * inv * k
    return result[0,0]

# %% [markdown]
# # Dataset -- R15

# %%
dataset = loadtxt("dataset\R15.txt")
data = array([dataset[:,0], dataset[:,1]])
clusters = dataset[:,2]
size = len(clusters)

X = data[0,:]
Y = data[1,:]

plotScatter(X,Y,"Scatter Plot", 'g')

# %%
grid_x = [0 + 0.5 * i for i in range (40) ] 
grid_y = [20 - 0.5 * i for i in range (40) ] 
alpha = 2
variances = [[0 for i in range (len(grid_x)) ] for j in range (len(grid_y))]

C = getCovarianceMatrix(data)
invA = getInversionMatrix(data, C)

for i in range (len(grid_y)):
    for j in range (len(grid_x)):
        variances[i][j] = varianceFunction([grid_x[j], grid_y[i]], data, invA)

# %%
heatmap = variances
extent = [grid_x[0], grid_x[-1], grid_y[-1], grid_y[0]]

plt.clf()
plt.imshow(heatmap, extent=extent)
plt.show()

# %% [markdown]
# # Dataset - Jain's Toy Problem

# %%
dataset = loadtxt("dataset\jain.txt")
data = array([dataset[:,0], dataset[:,1]])
clusters = dataset[:,2]
size = len(clusters)

X = data[0,:]
Y = data[1,:]

plotScatter(X,Y,"Scatter Plot", 'g')

# %%
grid_x = [0 + 1 * i for i in range (45) ] 
grid_y = [30 - 1 * i for i in range (30) ] 
alpha = 0.1
variances = [[0 for i in range (len(grid_x)) ] for j in range (len(grid_y))]

C = getCovarianceMatrix(data)
invA = getInversionMatrix(data, C)

for i in range (len(grid_y)):
    for j in range (len(grid_x)):
        variances[i][j] = varianceFunction([grid_x[j], grid_y[i]], data, invA)

# %%
heatmap = variances
extent = [grid_x[0], grid_x[-1], grid_y[-1], grid_y[0]]

plt.clf()
plt.imshow(heatmap, extent=extent)
plt.show()

# %% [markdown]
# # Dataset -- Aggregation

# %%
dataset = loadtxt("dataset\Aggregation.txt")
data = array([dataset[:,0], dataset[:,1]])
clusters = dataset[:,2]
size = len(clusters)

X = data[0,:]
Y = data[1,:]

plotScatter(X,Y,"Scatter Plot", 'g')

# %%
grid_x = [0 + 1 * i for i in range (40) ] 
grid_y = [30 - 1 * i for i in range (30) ] 
alpha = 1
variances = [[0 for i in range (len(grid_x)) ] for j in range (len(grid_y))]

C = getCovarianceMatrix(data)
invA = getInversionMatrix(data, C)

for i in range (len(grid_y)):
    for j in range (len(grid_x)):
        variances[i][j] = varianceFunction([grid_x[j], grid_y[i]], data, invA)

# %%
heatmap = variances
extent = [grid_x[0], grid_x[-1], grid_y[-1], grid_y[0]]

plt.clf()
plt.imshow(heatmap, extent=extent)
plt.show()

# %% [markdown]
# # Dataset - Spiral

# %%
dataset = loadtxt("dataset\spiral.txt")
data = array([dataset[:,0], dataset[:,1]])
clusters = dataset[:,2]
size = len(clusters)

X = data[0,:]
Y = data[1,:]

plotScatter(X,Y,"Scatter Plot", 'g')

# %%
grid_x = [0 + 1 * i for i in range (35) ] 
grid_y = [35 - 1 * i for i in range (35) ] 
alpha = 1
variances = [[0 for i in range (len(grid_x)) ] for j in range (len(grid_y))]

C = getCovarianceMatrix(data)
invA = getInversionMatrix(data, C)

for i in range (len(grid_y)):
    for j in range (len(grid_x)):
        variances[i][j] = varianceFunction([grid_x[j], grid_y[i]], data, invA)

# %%
heatmap = variances
extent = [grid_x[0], grid_x[-1], grid_y[-1], grid_y[0]]

plt.clf()
plt.imshow(heatmap, extent=extent)
plt.show()

# %% [markdown]
# # Dataset -- Path-bsed 1

# %%
dataset = loadtxt("dataset\Pathbased.txt")
data = array([dataset[:,0], dataset[:,1]])
clusters = dataset[:,2]
size = len(clusters)

X = data[0,:]
Y = data[1,:]

plotScatter(X,Y,"Scatter Plot", 'g')

# %%
grid_x = [0 + 1 * i for i in range (35) ] 
grid_y = [35 - 1 * i for i in range (35) ] 
alpha = 1
variances = [[0 for i in range (len(grid_x)) ] for j in range (len(grid_y))]

C = getCovarianceMatrix(data)
invA = getInversionMatrix(data, C)

for i in range (len(grid_y)):
    for j in range (len(grid_x)):
        variances[i][j] = varianceFunction([grid_x[j], grid_y[i]], data, invA)

# %%
heatmap = variances
extent = [grid_x[0], grid_x[-1], grid_y[-1], grid_y[0]]

plt.clf()
plt.imshow(heatmap, extent=extent)
plt.show()

# %% [markdown]
# # Dataset -- Zahn's Compound

# %%
dataset = loadtxt("dataset\Compound.txt")
data = array([dataset[:,0], dataset[:,1]])
clusters = dataset[:,2]
size = len(clusters)

X = data[0,:]
Y = data[1,:]
 
plotScatter(X,Y,"Scatter Plot", 'g')

# %%
grid_x = [5 + 1 * i for i in range (45) ] 
grid_y = [25 - 1 * i for i in range (20) ] 
alpha = 1
variances = [[0 for i in range (len(grid_x)) ] for j in range (len(grid_y))]

C = getCovarianceMatrix(data)
invA = getInversionMatrix(data, C)

for i in range (len(grid_y)):
    for j in range (len(grid_x)):
        variances[i][j] = varianceFunction([grid_x[j], grid_y[i]], data, invA)

# %%
heatmap = variances
extent = [grid_x[0], grid_x[-1], grid_y[-1], grid_y[0]]

plt.clf()
plt.imshow(heatmap, extent=extent)
plt.show()

# %%
print len(clusters)
# Out:
# 399

# %% [markdown]
# $$ L(r^*) := {x : \sigma^2(x) <= r^* } = C_1 \cup ... \cup C_p$$
